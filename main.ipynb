# %%
from demographics import (
    population,
    cpi,
    grdp,
    languages,
    population,
    transportation
)

from poverty import (
    income_gap,
    magnitude_poor_family,
    magnitude_poor_pop,
    magnitude_subsistence_poor_family,
    magnitude_subsistence_poor_pop,
    poverty_incidence_threshold_family,
    poverty_incidence_threshold_pop,
    severity_poverty,
    food_threshold_subsistence_family,
    food_threshold_subsistence_pop,
)
import location

# %% [markdown]
# #### Non-Numeric Fact Table

# %%
location_data = location.get()
# Out:
# c:\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# #### Demographics Dimension

# %%
population_data = population.get(location_data)
display(population_data)
# Out:
# File NCR.xlsx already exists
# File CAR.xlsx already exists
# File Region%201.xlsx already exists
# File Region%202.xlsx already exists
# File Region%203.xlsx already exists
# File Region%205.xlsx already exists
# File %281%29%20Region%206_final.xlsx already exists
# File Region%207.xlsx already exists
# File Region%208.xlsx already exists
# File Region%209.xlsx already exists
# File Region%2010.xlsx already exists
# File Region%2011.xlsx already exists
# File Region%2012.xlsx already exists
# File Caraga.xlsx already exists
# File BARMM.xlsx already exists
# File Region%204A.xlsx already exists
# File MIMAROPA.xlsx already exists
# Reading file NCR.xlsx
# Reading file CAR.xlsx
# (Quirino-Magsaysay, Lower) doesn't have a population count.  Removing from the database.
# Reading file Region%201.xlsx
# Reading file Region%202.xlsx
# Reading file Region%203.xlsx
# Reading file Region%205.xlsx
# Reading file %281%29%20Region%206_final.xlsx
# Reading file Region%207.xlsx
# ...

# %%
cpi_data = cpi.get(location_data)
display(cpi_data)

# %%
grdp_data = grdp.get(location_data)
display(grdp_data)

# %%
languages_data = languages.get(location_data)
display(languages_data)

# %%
transportation_data = transportation.get()
display(transportation_data)

# %% [markdown]
# #### Poverty Dimension

# %%
income_gap_data = income_gap.get()
display(income_gap_data)
# Out:
#       Geolocation  2015  2018  2021    ADM2_CODE
# 0    1st District  19.9  18.7   9.1  PH133900000
# 1    2nd District  15.1  13.7  15.6  PH137600000
# 2    3rd District  15.7  16.3  13.9  PH137400000
# 3    4th District  16.2  14.7  15.9  PH137500000
# 4            Abra  19.6  23.4  19.3  PH140100000
# ..            ...   ...   ...   ...          ...
# 82        Basilan  17.6  30.8  26.1  PH150700000
# 83  Lanao del Sur  32.2  30.3  10.4  PH153600000
# 84    Maguindanao  27.6  25.1  21.4  PH153800000
# 85           Sulu  20.9  27.4  24.5  PH156600000
# 86      Tawi-tawi  11.7  15.8  21.5  PH157000000
#
# [87 rows x 5 columns]

# %%
magnitude_poor_family_data = magnitude_poor_family.get()
display(magnitude_poor_family_data)
# Out:
#       Geolocation    2015    2018  2021p    ADM2_CODE
# 0    1st District   13.63    9.01   5.29  PH133900000
# 1    2nd District   22.28   16.47  19.79  PH137600000
# 2    3rd District   24.00   15.11  23.36  PH137400000
# 3    4th District   26.19    7.00  27.72  PH137500000
# 4            Abra   12.21    8.19   9.19  PH140100000
# ..            ...     ...     ...    ...          ...
# 82        Basilan   14.09   41.98  28.49  PH150700000
# 83  Lanao del Sur  120.16  109.12  13.25  PH153600000
# 84    Maguindanao   81.13   84.58  66.43  PH153800000
# 85           Sulu  107.88  110.00  78.81  PH156600000
# 86      Tawi-tawi   10.38   10.49  20.17  PH157000000
#
# [87 rows x 5 columns]

# %%
magnitude_poor_pop_data = magnitude_poor_pop.get()
display(magnitude_poor_family_data)
# Out:
#       Geolocation    2015    2018  2021p    ADM2_CODE
# 0    1st District   13.63    9.01   5.29  PH133900000
# 1    2nd District   22.28   16.47  19.79  PH137600000
# 2    3rd District   24.00   15.11  23.36  PH137400000
# 3    4th District   26.19    7.00  27.72  PH137500000
# 4            Abra   12.21    8.19   9.19  PH140100000
# ..            ...     ...     ...    ...          ...
# 82        Basilan   14.09   41.98  28.49  PH150700000
# 83  Lanao del Sur  120.16  109.12  13.25  PH153600000
# 84    Maguindanao   81.13   84.58  66.43  PH153800000
# 85           Sulu  107.88  110.00  78.81  PH156600000
# 86      Tawi-tawi   10.38   10.49  20.17  PH157000000
#
# [87 rows x 5 columns]

# %%
magnitude_subsistence_poor_family_data = magnitude_subsistence_poor_family.get()
display(magnitude_subsistence_poor_family_data)
# Out:
#       Geolocation   2015   2018  2021p    ADM2_CODE
# 0    1st District   3.32   2.16   0.00  PH133900000
# 1    2nd District   1.52   2.16   3.18  PH137600000
# 2    3rd District   3.65   3.29   1.60  PH137400000
# 3    4th District   3.94   0.46   4.31  PH137500000
# 4            Abra   3.23   2.44   1.98  PH140100000
# ..            ...    ...    ...    ...          ...
# 82        Basilan   3.34  21.60  10.96  PH150700000
# 83  Lanao del Sur  67.50  52.73   0.46  PH153600000
# 84    Maguindanao  32.75  31.36  18.48  PH153800000
# 85           Sulu  24.09  46.04  26.40  PH156600000
# 86      Tawi-tawi   0.32   1.43   4.59  PH157000000
#
# [87 rows x 5 columns]

# %%
magnitude_subsistence_poor_pop = magnitude_subsistence_poor_pop.get()
display(magnitude_subsistence_poor_pop)
# Out:
#       Geolocation    2015    2018   2021p    ADM2_CODE
# 0    1st District   25.26   12.83    0.00  PH133900000
# 1    2nd District   15.71   13.54   26.11  PH137600000
# 2    3rd District   20.29   24.86   12.08  PH137400000
# 3    4th District   22.84    2.84   25.37  PH137500000
# 4            Abra   23.18   14.62   13.17  PH140100000
# ..            ...     ...     ...     ...          ...
# 82        Basilan   26.94  156.84   94.41  PH150700000
# 83  Lanao del Sur  500.32  423.22    4.73  PH153600000
# 84    Maguindanao  239.04  254.74  168.50  PH153800000
# 85           Sulu  186.41  364.63  225.88  PH156600000
# 86      Tawi-tawi    2.50   13.62   42.06  PH157000000
#
# [87 rows x 5 columns]

# %%
poverty_incidence_threshold_family = poverty_incidence_threshold_family.get()
display(poverty_incidence_threshold_family)
# Out:
#       Geolocation Poverty Threshold 2015  Poverty Threshold 2018  \
# 0    1st District                  25188                   28682
# 1    2nd District                  25188                   28682
# 2    3rd District                  25188                   28682
# 3    4th District                  25188                   28682
# 4            Abra                  21294                   23596
# ..            ...                    ...                     ...
# 82        Basilan                  21472                   26951
# 83  Lanao del Sur                  24421                   29224
# 84    Maguindanao                  20399                   25368
# 85           Sulu                  23115                   29150
# 86      Tawi-tawi                  17666                   21264
#
#     Poverty Threshold 2021p Poverty Incidence 2015  Poverty Incidence 2018  \
# 0                     32978                    3.6                     1.9
# ...

# %%
poverty_incidence_threshold_pop = poverty_incidence_threshold_pop.get()
display(poverty_incidence_threshold_pop)
# Out:
#       Geolocation Poverty Threshold 2015  Poverty Threshold 2018  \
# 0    1st District                  25188                   28682
# 1    2nd District                  25188                   28682
# 2    3rd District                  25188                   28682
# 3    4th District                  25188                   28682
# 4            Abra                  21294                   23596
# ..            ...                    ...                     ...
# 82        Basilan                  21472                   26951
# 83  Lanao del Sur                  24421                   29224
# 84    Maguindanao                  20399                   25368
# 85           Sulu                  23115                   29150
# 86      Tawi-tawi                  17666                   21264
#
#     Poverty Threshold 2021p Poverty Incidence 2015  Poverty Incidence 2018  \
# 0                     32978                      5                       3
# ...

# %%
severity_poverty = severity_poverty.get()
display(severity_poverty)
# Out:
#       Geolocation Poverty Severity 2015 Poverty Severity 2018  \
# 0    1st District                   0.3                   0.1
# 1    2nd District                   0.1                   0.0
# 2    3rd District                   0.1                   0.1
# 3    4th District                   0.2                   0.0
# 4            Abra                   1.1                   1.1
# ..            ...                   ...                   ...
# 82        Basilan                   1.6                   8.1
# 83  Lanao del Sur                   9.5                   7.8
# 84    Maguindanao                   4.7                   3.7
# 85           Sulu                   3.7                   7.4
# 86      Tawi-tawi                   0.3                   0.6
#
#     Poverty Severity 2021p    ADM2_CODE
# 0                      0.0  PH133900000
# 1                      0.1  PH137600000
# 2                      0.1  PH137400000
# 3                      0.1  PH137500000
# ...

# %%
food_threshold_subsistence_family = food_threshold_subsistence_family.get()
display(food_threshold_subsistence_family)
# Out:
#       Geolocation Per Capita Food Threshold 2015  \
# 0    1st District                          17589
# 1    2nd District                          17589
# 2    3rd District                          17589
# 3    4th District                          17589
# 4            Abra                          14870
# ..            ...                            ...
# 82        Basilan                          15009
# 83  Lanao del Sur                          17041
# 84    Maguindanao                          14276
# 85           Sulu                          16205
# 86      Tawi-tawi                          12289
#
#     Per Capita Food Threshold 2018  Per Capita Food Threshold 2021p  \
# 0                            20029                            23028
# 1                            20029                            23028
# 2                            20029                            23028
# 3                            20029                            23028
# ...

# %%
food_threshold_subsistence_pop = food_threshold_subsistence_pop.get()
display(food_threshold_subsistence_pop)
# Out:
#       Geolocation Per Capita Food Threshold 2015  \
# 0    1st District                          17589
# 1    2nd District                          17589
# 2    3rd District                          17589
# 3    4th District                          17589
# 4            Abra                          14870
# ..            ...                            ...
# 82        Basilan                          15009
# 83  Lanao del Sur                          17041
# 84    Maguindanao                          14276
# 85           Sulu                          16205
# 86      Tawi-tawi                          12289
#
#     Per Capita Food Threshold 2018  Per Capita Food Threshold 2021p  \
# 0                            20029                            23028
# 1                            20029                            23028
# 2                            20029                            23028
# 3                            20029                            23028
# ...
